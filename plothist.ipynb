# %%
#open 0.7_0.7777777_n1001_nologit.csv using csv
import csv
with open('./datasets/0.7_0.7777777_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]

# %%
#plot data as a hist from 0.7 to 0.7777777 with 10 bins
import numpy as np
import matplotlib.pyplot as plt

# Create normalized histogram
plt.hist(data, bins=10, edgecolor='black', alpha=0.7, density=True)

# Title and labels
plt.title('Histogram of Data, floats from 0.7 to 0.7777777, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Density')

# Show plot
plt.show()

# %%
#open 0.7_0.7777777_n1001_nologit.csv using csv
import csv
with open('./datasets/0.6_0.7777777_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]

# %%
#plot data as a hist from 0.7 to 0.7777777 with 10 bins
import numpy as np
import matplotlib.pyplot as plt

# Create normalized histogram
plt.hist(data, bins=10, edgecolor='black', alpha=0.7, density=True)

# Title and labels
plt.title('Histogram of Data, floats from 0.6 to 0.7777777, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Density')

# Show plot
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
with open('./datasets/0_100_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]

# Create normalized histogram
plt.hist(data, bins=10, edgecolor='black', alpha=0.7, density=True)

# Title and labels
plt.title('Histogram of Data, floats from 0 to 100, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Density')

# Show plot
plt.show()

# %%
strdata=[str(i) for i in data]
print("The amount of numbers in the set containing the number 7 is:",len([i for i in strdata if "7" in i]))
print("The amount of numbers starting with 7 is:",len([i for i in strdata if i[0]=="7"]))
# #plot data as a hist from 0.7 to 0.7777777 with 10 bins
# import numpy as np
# import matplotlib.pyplot as plt

# # Create normalized histogram
# plt.hist(data, bins=10, edgecolor='black', alpha=0.7, density=True)

# # Title and labels
# plt.title('Histogram of Data, floats from 0.7 to 0.7777777, n= '+str(len(data)))
# plt.xlabel('Value')
# plt.ylabel('Density')

# # Show plot
plt.show()
# Out:
# The amount of numbers in the set containing the number 7 is: 519
# The amount of numbers starting with 7 is: 250

# %%
import csv
with open('./datasets/0_6_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]

#plot data as a hist from 0.7 to 0.7777777 with 10 bins
import numpy as np
import matplotlib.pyplot as plt

# Create normalized histogram
plt.hist(data, bins=10, edgecolor='black', alpha=0.7, density=True)

# Title and labels
plt.title('Histogram of Data, floats from 0.7 to 0.7777777, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Density')

# Show plot
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open('./datasets/-5_5_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]
print(len(data))

# Create normalized histogram
plt.hist(data, bins=range(-5,6), edgecolor='black', alpha=0.7, density=True)

# Title and labels
plt.title('Histogram of Data, floats from -5 to 5, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Density')

# Show plot
plt.show()
# Out:
# 999

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open('./datasets/-50_50_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]
print(len(data))

# Create normalized histogram
bins=[-50,-40,-30,-20,-10,0,10,20,30,40,50]
plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)

# Title and labels
plt.title('Histogram of Data, floats from -50 to 50, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Counts')

# Show plot
plt.show()
# Out:
# 1001

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open('0.0_1.0_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]
print(len(data))

bins=np.arange(0.0, 1.1, 0.1)

# Create normalized histogram
plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)

# Title and labels
plt.title('Histogram of Data, floats from 0.0 to 1.0, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Counts')

# Show plot
plt.show()
# Out:
# 996

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open('4.0_5.0_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]
print(len(data))

bins=np.arange(4.0, 5.1, 0.1)

# Create normalized histogram
plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)

# Title and labels
plt.title('Histogram of Data, floats from 4.0 to 5.0, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Counts')

# Show plot
plt.show()
# Out:
# 993

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open('-0.5_0.5_n1001_nologitv3.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]
print(len(data))

bins=np.arange(-0.5, 0.6, 0.1)

# Create normalized histogram
plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)

# Title and labels
plt.title('Trial 1: Histogram of Data, floats from 0.0 to 1.0, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Counts')

# Show plot
plt.show()
# Out:
# 998

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open('-0.5_0.5_n1001_nologitv2.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]
print(len(data))

bins=np.arange(-0.5, 0.6, 0.1)

# Create normalized histogram
plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)

# Title and labels
plt.title('Trial 2: Histogram of Data, floats from 0.0 to 1.0, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Counts')

# Show plot
plt.show()
# Out:
# 998

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open('-0.5_0.5_n1001_nologit.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
data=[float(n[0]) for n in data if n[0]!="" and n[0]!="\n" and n[0]!="None"]
print(len(data))

bins=np.arange(-0.5, 0.6, 0.1)

# Create normalized histogram
plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)

# Title and labels
plt.title('Trial 3: Histogram of Data, floats from 0.0 to 1.0, n= '+str(len(data)))
plt.xlabel('Value')
plt.ylabel('Counts')

# Show plot
plt.show()
# Out:
# 1001
